# %%
import pyfolio as pf
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline


# silence warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load data from catalyst\zipline

# %%
perf = pd.read_csv('perf_TradingPair(452516 [eth_btc]).csv', index_col = 'Unnamed: 0')
perf.index = pd.to_datetime(perf.index)
perf.head()
# Out:
#                      algo_volatility  algorithm_period_return     alpha  \
# 2017-12-01 23:59:00              NaN                 0.000000       NaN
# 2017-12-02 23:59:00         0.027645                -0.002463 -1.324169
# 2017-12-03 23:59:00         0.162890                 0.013910  2.958721
# 2017-12-04 23:59:00         0.188476                 0.035683  1.764807
# 2017-12-05 23:59:00         0.197840                 0.061165 -1.196615
#
#                          amount  benchmark_period_return  \
# 2017-12-01 23:59:00    0.000000                -0.027224
# 2017-12-02 23:59:00 -235.571260                -0.041294
# 2017-12-03 23:59:00 -235.571260                -0.057221
# 2017-12-04 23:59:00 -196.466431                -0.078785
# 2017-12-05 23:59:00 -196.466431                -0.108506
#
#                      benchmark_volatility      beta  brick_size  capital_used  \
# 2017-12-01 23:59:00                   NaN       NaN     0.00129      0.000000
# ...

# %% [markdown]
# ### Look at stats

# %%
pf.show_perf_stats(perf.returns)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2017-12-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-11-12</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>16</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>149.7%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>252.6%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>39.8%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.49</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>7.99</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.80</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-18.7%</td>
#     </tr>
#     <tr>
# ...

# %%
pf.show_worst_drawdown_periods(perf.returns)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>18.74</td>
#       <td>2018-09-21</td>
#       <td>2018-11-07</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16.12</td>
#       <td>2017-12-13</td>
#       <td>2017-12-16</td>
#       <td>2017-12-21</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>11.25</td>
#       <td>2018-06-19</td>
#       <td>2018-07-08</td>
#       <td>2018-07-23</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10.31</td>
#       <td>2018-08-02</td>
#       <td>2018-08-12</td>
#       <td>2018-09-04</td>
#       <td>24</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Let's draw some graphs

# %%
plt.figure(figsize = (15, 10))
plt.plot(perf.benchmark_period_return)
plt.plot(perf.algorithm_period_return)
plt.legend()
plt.ylabel('Equity')
plt.xlabel('Date')
# Out:
# Text(0.5,0,'Date')

# %%
plt.figure(figsize = (15, 10))
pf.plot_drawdown_underwater(perf.returns).set_xlabel('Date')
# Out:
# Text(0.5,0,'Date')

# %%
plt.figure(figsize = (15, 10))
pf.plot_drawdown_periods(perf.returns, top = 5).set_xlabel('Date')
# Out:
# Text(0.5,0,'Date')

# %%
plt.figure(figsize = (15, 10))
pf.plot_returns(perf.returns).set_xlabel('Date')
# Out:
# Text(0.5,0,'Date')

# %%
plt.figure(figsize = (15, 10))
pf.plot_return_quantiles(perf.returns).set_xlabel('Timeframe')
# Out:
# Text(0.5,0,'Timeframe')

# %%
plt.figure(figsize = (15, 10))
pf.plot_monthly_returns_dist(perf.returns).set_xlabel('Returns')
# Out:
# Text(0.5,0,'Returns')

# %%
plt.figure(figsize = (15, 10))
pf.plot_rolling_volatility(perf.returns, rolling_window = 30).set_xlabel('Date')
# Out:
# Text(0.5,0,'Date')

# %%
plt.figure(figsize = (15, 10))
pf.plot_rolling_sharpe(perf.returns, rolling_window = 30).set_xlabel('Date')
# Out:
# Text(0.5,0,'Date')
